# %% [markdown]
# #### Import Dependencies

# %%
import pandas as pd
import os
import csv
import numpy as np

# %% [markdown]
# #### Store filepath in a variable

# %%
csv_path = os.path.join("GlobalLandTemperaturesByCountry - Copy.csv")
csv_path
# Out:
# 'GlobalLandTemperaturesByCountry - Copy.csv'

# %%
temp_df = pd.read_csv(csv_path)
temp_df
# Out:
#                 dt  AverageTemperature  AverageTemperatureUncertainty  \
# 0       1743-11-01               4.384                          2.294
# 1       1743-12-01                 NaN                            NaN
# 2       1744-01-01                 NaN                            NaN
# 3       1744-02-01                 NaN                            NaN
# 4       1744-03-01                 NaN                            NaN
# ...            ...                 ...                            ...
# 577457  2013-05-01              19.059                          1.022
# 577458  2013-06-01              17.613                          0.473
# 577459  2013-07-01              17.000                          0.453
# 577460  2013-08-01              19.759                          0.717
# 577461  2013-09-01                 NaN                            NaN
#
#          Country
# 0          Åland
# 1          Åland
# 2          Åland
# 3          Åland
# 4          Åland
# ...

# %%
temp_df.head()
# Out:
#            dt  AverageTemperature  AverageTemperatureUncertainty Country
# 0  1743-11-01               4.384                          2.294   Åland
# 1  1743-12-01                 NaN                            NaN   Åland
# 2  1744-01-01                 NaN                            NaN   Åland
# 3  1744-02-01                 NaN                            NaN   Åland
# 4  1744-03-01                 NaN                            NaN   Åland

# %%
countries_df = temp_df.loc[(temp_df["Country"]== "Brazil") |(temp_df["Country"]== "United States"),:]
countries_df
# Out:
#                 dt  AverageTemperature  AverageTemperatureUncertainty  \
# 77110   1832-01-01              24.935                          1.372
# 77111   1832-02-01              24.505                          1.953
# 77112   1832-03-01              24.617                          1.359
# 77113   1832-04-01              23.990                          2.013
# 77114   1832-05-01              23.124                          1.592
# ...            ...                 ...                            ...
# 557816  2013-05-01              14.073                          0.178
# 557817  2013-06-01              20.198                          0.236
# 557818  2013-07-01              22.074                          0.152
# 557819  2013-08-01              21.168                          0.249
# 557820  2013-09-01              18.273                          1.210
#
#               Country
# 77110          Brazil
# 77111          Brazil
# 77112          Brazil
# 77113          Brazil
# ...

# %%
countries_df['dt'] = pd.to_datetime(countries_df['dt'])
countries_df['Year'] = countries_df['dt'].dt.year
countries_df
# Out:
# C:\Users\lourd\Anaconda\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\lourd\Anaconda\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                dt  AverageTemperature  AverageTemperatureUncertainty  \
# 77110  1832-01-01              24.935                          1.372
# 77111  1832-02-01              24.505                          1.953
# ...

# %%
frame = countries_df.reset_index()
frame
# Out:
#        index         dt  AverageTemperature  AverageTemperatureUncertainty  \
# 0      77110 1832-01-01              24.935                          1.372
# 1      77111 1832-02-01              24.505                          1.953
# 2      77112 1832-03-01              24.617                          1.359
# 3      77113 1832-04-01              23.990                          2.013
# 4      77114 1832-05-01              23.124                          1.592
# ...      ...        ...                 ...                            ...
# 5117  557816 2013-05-01              14.073                          0.178
# 5118  557817 2013-06-01              20.198                          0.236
# 5119  557818 2013-07-01              22.074                          0.152
# 5120  557819 2013-08-01              21.168                          0.249
# 5121  557820 2013-09-01              18.273                          1.210
#
#             Country  Year
# 0            Brazil  1832
# ...

# %%
frame_v1 = frame.drop(frame.index[0:2016])
frame_v1
# Out:
#        index         dt  AverageTemperature  AverageTemperatureUncertainty  \
# 2016   79126 2000-01-01              25.653                          0.155
# 2017   79127 2000-02-01              25.463                          0.162
# 2018   79128 2000-03-01              25.446                          0.187
# 2019   79129 2000-04-01              25.102                          0.092
# 2020   79130 2000-05-01              24.614                          0.216
# ...      ...        ...                 ...                            ...
# 5117  557816 2013-05-01              14.073                          0.178
# 5118  557817 2013-06-01              20.198                          0.236
# 5119  557818 2013-07-01              22.074                          0.152
# 5120  557819 2013-08-01              21.168                          0.249
# 5121  557820 2013-09-01              18.273                          1.210
#
#             Country  Year
# 2016         Brazil  2000
# ...

# %%
frame_v2 = frame_v1.reset_index()
frame_v2
# Out:
#       level_0   index         dt  AverageTemperature  \
# 0        2016   79126 2000-01-01              25.653
# 1        2017   79127 2000-02-01              25.463
# 2        2018   79128 2000-03-01              25.446
# 3        2019   79129 2000-04-01              25.102
# 4        2020   79130 2000-05-01              24.614
# ...       ...     ...        ...                 ...
# 3101     5117  557816 2013-05-01              14.073
# 3102     5118  557817 2013-06-01              20.198
# 3103     5119  557818 2013-07-01              22.074
# 3104     5120  557819 2013-08-01              21.168
# 3105     5121  557820 2013-09-01              18.273
#
#       AverageTemperatureUncertainty        Country  Year
# 0                             0.155         Brazil  2000
# 1                             0.162         Brazil  2000
# 2                             0.187         Brazil  2000
# 3                             0.092         Brazil  2000
# ...

# %%
frame_v3 = frame_v2.drop(frame_v2.index[165:2941])
frame_v3
# Out:
#       level_0   index         dt  AverageTemperature  \
# 0        2016   79126 2000-01-01              25.653
# 1        2017   79127 2000-02-01              25.463
# 2        2018   79128 2000-03-01              25.446
# 3        2019   79129 2000-04-01              25.102
# 4        2020   79130 2000-05-01              24.614
# ...       ...     ...        ...                 ...
# 3101     5117  557816 2013-05-01              14.073
# 3102     5118  557817 2013-06-01              20.198
# 3103     5119  557818 2013-07-01              22.074
# 3104     5120  557819 2013-08-01              21.168
# 3105     5121  557820 2013-09-01              18.273
#
#       AverageTemperatureUncertainty        Country  Year
# 0                             0.155         Brazil  2000
# 1                             0.162         Brazil  2000
# 2                             0.187         Brazil  2000
# 3                             0.092         Brazil  2000
# ...

# %%
frame_temperature_f = frame_v3.drop(columns=['level_0', 'index', 'dt', 'AverageTemperatureUncertainty'])
frame_temperature_f
# Out:
#       AverageTemperature        Country  Year
# 0                 25.653         Brazil  2000
# 1                 25.463         Brazil  2000
# 2                 25.446         Brazil  2000
# 3                 25.102         Brazil  2000
# 4                 24.614         Brazil  2000
# ...                  ...            ...   ...
# 3101              14.073  United States  2013
# 3102              20.198  United States  2013
# 3103              22.074  United States  2013
# 3104              21.168  United States  2013
# 3105              18.273  United States  2013
#
# [330 rows x 3 columns]

# %%
frame_temperature_f2 = frame_temperature_f.groupby(['Country','Year']).max()
frame_temperature_f2
# Out:
#                     AverageTemperature
# Country       Year
# Brazil        2000              26.393
#               2001              26.507
#               2002              26.956
#               2003              26.540
#               2004              26.486
#               2005              26.794
#               2006              26.301
#               2007              26.689
#               2008              26.678
#               2009              27.151
#               2010              26.802
#               2011              26.373
#               2012              27.120
#               2013              26.239
# United States 2000              21.605
#               2001              21.907
#               2002              22.675
#               2003              22.499
#               2004              21.663
#               2005              22.478
#               2006              22.911
#               2007              22.352
# ...

# %%
frame_temperature_f3 = frame_temperature_f2.rename(columns={'AverageTemperature': 'Max Annual Temperature C'})
frame_temperature_f3
# Out:
#                     Max Annual Temperature C
# Country       Year
# Brazil        2000                    26.393
#               2001                    26.507
#               2002                    26.956
#               2003                    26.540
#               2004                    26.486
#               2005                    26.794
#               2006                    26.301
#               2007                    26.689
#               2008                    26.678
#               2009                    27.151
#               2010                    26.802
#               2011                    26.373
#               2012                    27.120
#               2013                    26.239
# United States 2000                    21.605
#               2001                    21.907
#               2002                    22.675
#               2003                    22.499
#               2004                    21.663
# ...

# %%
frame_temperature_final = frame_temperature_f3.reset_index()
frame_temperature_final
# Out:
#           Country  Year  Max Annual Temperature C
# 0          Brazil  2000                    26.393
# 1          Brazil  2001                    26.507
# 2          Brazil  2002                    26.956
# 3          Brazil  2003                    26.540
# 4          Brazil  2004                    26.486
# 5          Brazil  2005                    26.794
# 6          Brazil  2006                    26.301
# 7          Brazil  2007                    26.689
# 8          Brazil  2008                    26.678
# 9          Brazil  2009                    27.151
# 10         Brazil  2010                    26.802
# 11         Brazil  2011                    26.373
# 12         Brazil  2012                    27.120
# 13         Brazil  2013                    26.239
# 14  United States  2000                    21.605
# 15  United States  2001                    21.907
# 16  United States  2002                    22.675
# 17  United States  2003                    22.499
# ...

# %%
temp_us = frame_temperature_final.drop(frame_temperature_final.index[0:14])
temp_us
# Out:
#           Country  Year  Max Annual Temperature C
# 14  United States  2000                    21.605
# 15  United States  2001                    21.907
# 16  United States  2002                    22.675
# 17  United States  2003                    22.499
# 18  United States  2004                    21.663
# 19  United States  2005                    22.478
# 20  United States  2006                    22.911
# 21  United States  2007                    22.352
# 22  United States  2008                    21.690
# 23  United States  2009                    21.463
# 24  United States  2010                    22.078
# 25  United States  2011                    22.722
# 26  United States  2012                    23.008
# 27  United States  2013                    22.074

# %%
temp_br = frame_temperature_final.drop(frame_temperature_final.index[14:27])
temp_br
# Out:
#           Country  Year  Max Annual Temperature C
# 0          Brazil  2000                    26.393
# 1          Brazil  2001                    26.507
# 2          Brazil  2002                    26.956
# 3          Brazil  2003                    26.540
# 4          Brazil  2004                    26.486
# 5          Brazil  2005                    26.794
# 6          Brazil  2006                    26.301
# 7          Brazil  2007                    26.689
# 8          Brazil  2008                    26.678
# 9          Brazil  2009                    27.151
# 10         Brazil  2010                    26.802
# 11         Brazil  2011                    26.373
# 12         Brazil  2012                    27.120
# 13         Brazil  2013                    26.239
# 27  United States  2013                    22.074

# %%
final_us_temp = temp_us.rename(columns={"Max Annual Temperature C" : "US Max Annual Temperature"})

# %%
final_us_df = final_us_temp.drop(['Country'], axis=1)

# %%
final_br_temp = temp_br.rename(columns={"Max Annual Temperature C" : "Brazil Max Annual Temperature"})

# %%
final_br_df = final_br_temp.drop(['Country'], axis=1)

# %%
summary_temp_df = final_us_df.merge(final_br_df, on='Year')

# %%
summary_final = summary_temp_df.drop(summary_temp_df.index[14])
summary_final
# Out:
#     Year  US Max Annual Temperature  Brazil Max Annual Temperature
# 0   2000                     21.605                         26.393
# 1   2001                     21.907                         26.507
# 2   2002                     22.675                         26.956
# 3   2003                     22.499                         26.540
# 4   2004                     21.663                         26.486
# 5   2005                     22.478                         26.794
# 6   2006                     22.911                         26.301
# 7   2007                     22.352                         26.689
# 8   2008                     21.690                         26.678
# 9   2009                     21.463                         27.151
# 10  2010                     22.078                         26.802
# 11  2011                     22.722                         26.373
# 12  2012                     23.008                         27.120
# ...

# %%
output_file = os.path.join("MaxTemperature.csv")
summary_final.to_csv(output_file, index=False, header=True)
