# %% [markdown]
# Springnature API

# %%
import pandas as pd
from bs4 import BeautifulSoup as bs
import requests
import pymongo
from splinter import Browser

# %%
table_fire = pd.read_html('https://www.ncdc.noaa.gov/societal-impacts/wildfires/ytd/0?params[]=acres&params[]=fires&params[]=apf')
table_fire_us = table_fire[0]

# %%
table_fire_us
# Out:
#        Date  Number of Fires  Acres Burned  Acres Burned per Fire
# 0    200001             2796         40757                   14.6
# 1    200002             8467        208967                   24.7
# 2    200003            18779        549866                   29.3
# 3    200004            28015        732579                   26.1
# 4    200005            39865       1027072                   25.8
# ..      ...              ...           ...                    ...
# 235  201908            35956       4237043                  117.8
# 236  201909            42583       4432941                  104.1
# 237  201910            44897       4566954                  101.7
# 238  201911            47217       4616654                   97.8
# 239  201912            49786       4630007                   93.0
#
# [240 rows x 4 columns]

# %%
table_fire_us['Date'] = table_fire_us['Date'].mask((table_fire_us['Date'] >= 200001) & (table_fire_us['Date'] < 200101), 2000)
table_fire_us['Date'] = table_fire_us['Date'].mask((table_fire_us['Date'] >= 200101) & (table_fire_us['Date'] < 200201), 2001)
table_fire_us['Date'] = table_fire_us['Date'].mask((table_fire_us['Date'] >= 200201) & (table_fire_us['Date'] < 200301), 2002)
table_fire_us['Date'] = table_fire_us['Date'].mask((table_fire_us['Date'] >= 200301) & (table_fire_us['Date'] < 200401), 2003)
table_fire_us['Date'] = table_fire_us['Date'].mask((table_fire_us['Date'] >= 200401) & (table_fire_us['Date'] < 200501), 2004)
table_fire_us['Date'] = table_fire_us['Date'].mask((table_fire_us['Date'] >= 200501) & (table_fire_us['Date'] < 200601), 2005)
table_fire_us['Date'] = table_fire_us['Date'].mask((table_fire_us['Date'] >= 200601) & (table_fire_us['Date'] < 200701), 2006)
table_fire_us['Date'] = table_fire_us['Date'].mask((table_fire_us['Date'] >= 200701) & (table_fire_us['Date'] < 200801), 2007)
table_fire_us['Date'] = table_fire_us['Date'].mask((table_fire_us['Date'] >= 200801) & (table_fire_us['Date'] < 200901), 2008)
table_fire_us['Date'] = table_fire_us['Date'].mask((table_fire_us['Date'] >= 200901) & (table_fire_us['Date'] < 201001), 2009)
table_fire_us['Date'] = table_fire_us['Date'].mask((table_fire_us['Date'] >= 201001) & (table_fire_us['Date'] < 201101), 2010)
table_fire_us['Date'] = table_fire_us['Date'].mask((table_fire_us['Date'] >= 201101) & (table_fire_us['Date'] < 201201), 2011)
table_fire_us['Date'] = table_fire_us['Date'].mask((table_fire_us['Date'] >= 201201) & (table_fire_us['Date'] < 201301), 2012)
table_fire_us['Date'] = table_fire_us['Date'].mask((table_fire_us['Date'] >= 201301), 2013)

# %%
table_fire_us.head(100)
# Out:
#     Date  Number of Fires  Acres Burned  Acres Burned per Fire
# 0   2000             2796         40757                   14.6
# 1   2000             8467        208967                   24.7
# 2   2000            18779        549866                   29.3
# 3   2000            28015        732579                   26.1
# 4   2000            39865       1027072                   25.8
# ..   ...              ...           ...                    ...
# 95  2007            85705       9328045                  108.8
# 96  2008             1380         40804                   29.6
# 97  2008             5829        254987                   43.7
# 98  2008            11088        516243                   46.6
# 99  2008            19330       1274533                   65.9
#
# [100 rows x 4 columns]

# %%
table_fire_us_count = table_fire_us.groupby(['Date']).sum()

# %%
table_fire_us_count
# Out:
#       Number of Fires  Acres Burned  Acres Burned per Fire
# Date
# 2000           630036      42288795                  621.7
# 2001           515265      20488558                  417.1
# 2002           515327      42395261                  717.0
# 2003           381596      20330648                  466.7
# 2004           468610      46986494                  854.4
# 2005           408065      47770924                  960.7
# 2006           669091      61762108                 1038.8
# 2007           563505      50630942                  768.6
# 2008           515701      34091987                  710.4
# 2009           571906      36729144                  627.1
# 2010           424966      20145770                  455.9
# 2011           482359      57648174                 1181.1
# 2012           389901      51493589                 1140.2
# 2013          2512461     271594885                 6792.1

# %%
url_br = 'http://queimadas.dgi.inpe.br/queimadas/portal-static/situacao-atual/'

# %%
executable_path = {'executable_path': 'chromedriver.exe'}
browser = Browser('chrome', **executable_path, headless=False)

# %%
browser.visit(url_br)

# %%
html = browser.html
 # Parse HTML with Beautiful Soup
soup = bs(html, 'html.parser')

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html xmlns="http://www.w3.org/1999/xhtml">
#  <head lang="pt-br">
#   <meta charset="utf-8"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <meta content="Área Queimada - Programa Queimadas - INPE" name="title"/>
#   <meta content="index,follow" name="robots"/>
#   <title>
#    Situação atual - Programa Queimadas - INPE
#   </title>
#   <link href="assets/css/page.min.css" rel="stylesheet"/>
#   <link href="assets/css/base_plugin.css?_=01112002" rel="stylesheet"/>
#   <link href="assets/css/all.min.css" rel="stylesheet"/>
#   <link href="assets/jquery/jquery-ui.min.css" rel="stylesheet"/>
#   <link href="https://unpkg.com/leaflet@1.5.1/dist/leaflet.css" rel="stylesheet"/>
#   <link href="assets/leaflet/fullscreen/leaflet.fullscreen.css" rel="stylesheet"/>
#   <link href="assets/leaflet/geosearch/geosearch.css" rel="stylesheet"/>
#   <!-- HTML5 shim and Respond.js for IE8 support of HTML5 elements and media queries -->
#   <!--[if lt IE 9]>
#   <script src="//cdnjs.cloudflare.com/ajax/libs/html5shiv/3.7.2/html5shiv.min.js"></script>
#   <script src="//cdnjs.cloudflare.com/ajax/libs/respond.js/1.4.2/respond.min.js"></script>
#   <![endif]-->
#   <style type="text/css">
#    iframe{border:0;margin:0;padding:0;width:100%;min-height:560px;}
# ul{list-style:none;}
# ul {
#     display: block;
#     margin-block-start: 1em;
#     margin-block-end: 1em;
#     margin-inline-start: 0px;
#     margin-inline-end: 0px;
#     padding-inline-start: 40px;
# }
# #featured-content div.width-16{padding-top:49px !important;}
# .ui-state-active{background:#F19B1F!important;border:#F8CD8F;}
# .ui-state-collapsed{background:#F6F6F6!important;border:#556B87;}
# #featured-content div.width-16{padding-top:49px !important;}
#
# .espaco_esquerda{padding-left:60px;}
# .espaco_direita{padding-right:60px;text-align:right;}
# .tab_comparativa{font-size:12px;border:1px solid #666;border-radius:6px;padding:7px;margin:5px;overflow-y:auto;}
# .tb_dados{margin-left:11px;margin-top:10px;width:422px;}
# .tb_dados tr{background-color:#FADAAB;}
# .tb_dados tr:nth-child(even){background-color:#FDF2E3;}
#
# .inline li{background-color:#fff;border:2px solid #fff;border-radius:3px;-moz-border-radius:3px;-webkit-border-radius:3px;font-size:1.2em;cursor:pointer;}
# .inline li.active{color:#F19B1F;cursor:default;}
#
# /* .img_ano_atual{background-position:32px 0 !important;}
# .img_mes_atual{background-position:0 0 !important;}
# .img_48h{background-position:46px 0 !important;}
# .img_tabela{background-position:18px 0 !important;}
# .img_pizza{background-position:0 15px !important;}
# .img_barra{background-position:30px 15px !important;}
# .img_mapa{background-position:46px 45px !important;} */
#
# .content-mapa{width:100%;margin:0;padding:0;}
# .mapa{position:relative;width:100%;margin:2em 0 0 0;}
# .mapa label{font-size:1.4em;font-weight:bold;padding:0;margin:0;}
# #legenda_mapa{position:absolute;right:1px;bottom:18px;width:100%;height:auto;max-width:479px;max-height:34px;border:1px solid #fff;border-radius:3px;z-index:1000;opacity:.8;-moz-opacity:.8;-webkit-opacity:.8;filter:opacity(80)}
# #dvTituloMapa{width:100%;height:auto;border:1px solid #666;border-radius:6px 6px 0 0;}
# #dvTituloMapa&gt;span{display:block;padding:10px;border-top:3px solid #f19b1f;border-radius:3px;font-weight:bold;font-size:1.2em}
# #mapa{position:relative;min-height:640px;max-height:60vh;width: 100%;border: 1px solid #000;margin-top:-1px}
# #tituloMapa{display:inline-block;width:50%;}
# #subtituloMapa{display:inline-block;text-align:right;width:50%;}
# .legenda{display:block;width:100%;margin-top:.8em;text-align:center;font-style:italic;font-size:1.2em;cursor:default;}
# #slider{position:relative;margin: 15px 15px 15px 20px;}
#
# .estatisticas{display:block;width:100%;}
# .estatisticas .estatistica{display:inline-block;width:calc(50% - 2.2em);min-height:500px;padding:0;margin:2em 1em 0 1em;border:1px solid #666;border-radius: 6px;}
# .estatisticas .estatistica&gt;div{display:block;padding:.5em 1em .4em 1em;border-top:3px solid #f19b1f;border-bottom:1px solid #f9d7a5;border-radius:3px;font-size:1.2em}
# .estatisticas .titulo,.estatisticas ul{display:inline-block !important;}
# .estatisticas .inline li{display:inline-block;padding:0 .2em;}
# .estatisticas ul{width:42%;}
# .estatisticas .titulo{width:57%;color:#444;font-size:1.2em;cursor:default;}
# .estatisticas .estatistica table{width: 300px;}
# .estatisticas .estatistica h2{display: inline-block;width: auto;}
# .estatisticas .estatistica ul{margin:0;padding:0;}
#
# .comparativo{padding:.5em;margin-bottom:1em;}
# .comparativo iframe{min-height:auto;}
# .comparativo&gt;*{display:inline-block;}
# .comparativo&gt;span{display:block;width:100%;font-size:1.2em;}
# .comparativo ul{display:block;width:100% !important;margin-top:0;text-align:right;z-index:1000;}
# .comparativo li{text-align:center;cursor:pointer;}
# .descTempo{display:block;margin:0 .5em .5em .5em;font-size:1.2em;cursor:default;}
# .comparativo section{display:block;height:auto;border-top:1px solid #f9d7a5;width:100%;margin-top:-1px;padding:4px;padding-top:1em;z-index:0;}
# .comparativo section&gt;*{display:block;width:100%;padding:0;}
# .comparativo section a{font-size:1.2em;text-align:right;}
# .comparativo section a:hover{text-decoration:underline;}
#
# @media(max-width:576px){
#     #main h1,#main h2{margin-top:1em;font-size:1.6em !important;}
#     #sobre ul{max-width:100%;}
#     .estatisticas{width:100%;}
#     .estatisticas .estatistica{width:calc(100% - 2.2em);margin-left:0;}
#     .estatisticas .titulo{width:42%;font-size:.8em;}
#     .estatisticas ul{width:56%;}
#     #tituloMapa,#subtituloMapa{font-size:.8em;}
# }
#
# @media(max-width:769px){
#     .estatisticas{width:100%;}
#     .estatisticas .estatistica{width:calc(100% - 2.2em);}
#     .estatisticas .titulo{width:67%;}
#     .estatisticas ul{width:32%;}
# }
# @media(max-width:992px){
#     .estatisticas .titulo{width:48%;}
#     .estatisticas ul{width:50%;}
# }
#
# #dvCorpo{background-color:#f19b1f;border:1px solid #444;border-radius:5px;font-size:14px;height:779px;margin-left:12px;width:961px;}
#
# 	.loader{position:fixed;left:0;top:0;width:100%;height:100%;background-color:rgba(0,0,0,.7);display:none !important;}
# 	.loader img{position:absolute;left:calc(50% - 75px);top:calc(50% - 75px);width:150px;height:150px;}
#   </style>
#   <script async="" src="https://www.google-analytics.com/analytics.js" type="text/javascript">
#   </script>
#   <script src="https://code.jquery.com/jquery-3.4.1.min.js" type="text/javascript">
#   </script>
#   <script src="assets/jquery/jquery-ui.js" type="text/javascript">
#   </script>
#   <script src="https://unpkg.com/leaflet@1.5.1/dist/leaflet.js">
#   </script>
#   <script src="assets/leaflet/fullscreen/Leaflet.fullscreen.min.js">
#   </script>
#   <script src="assets/leaflet/geosearch/geosearch.js">
#   </script>
#   <script>
#    var loaded=0,n_frames;
# 		function resizeIframe(obj){try{obj.style.height = (obj.id=="comparativa-regiao")?'100px':(obj.contentWindow.document.body.scrollHeight + 'px');}catch(e){console.log("erro:",e)}finally{loaded++;checkLoaded();}}
# 		function checkLoaded(){if(loaded&gt;=n_frames-1){$(".loader").hide();}}
#   </script>
#  </head>
#  <body>
#   <div id="barra-identidade">
#    <div id="barra-brasil">
#     <div id="wrapper-barra-brasil">
#      <div class="brasil-flag">
#       <a class="link-barra" href="http://brasil.gov.br">
#        Brasil
#       </a>
#      </div>
#      <span class="acesso-info">
#       <a class="link-barra" href="http://www.servicos.gov.br/?pk_campaign=barrabrasil" id="barra-brasil-orgao">
#        Serviços
#       </a>
#      </span>
#      <nav>
#       <ul class="list" id="lista-barra-brasil">
#        <li>
#         <a href="#" id="menu-icon">
#         </a>
#        </li>
#        <li class="list-item first">
#         <a class="link-barra" href="http://www.simplifique.gov.br">
#          Simplifique!
#         </a>
#        </li>
#        <li class="list-item">
#         <a class="link-barra" href="http://brasil.gov.br/barra#participe">
#          Participe
#         </a>
#        </li>
#        <li class="list-item">
#         <a class="link-barra" href="http://brasil.gov.br/barra#acesso-informacao">
#          Acesso à informação
#         </a>
#        </li>
#        <li class="list-item">
#         <a class="link-barra" href="http://www.planalto.gov.br/legislacao">
#          Legislação
#         </a>
#        </li>
#        <li class="list-item last last-item">
#         <a class="link-barra" href="http://brasil.gov.br/barra#orgaos-atuacao-canais">
#          Canais
#         </a>
#        </li>
#       </ul>
#      </nav>
#      <span id="brasil-vlibras">
#       <a class="logo-vlibras" href="#">
#       </a>
#       <span class="link-vlibras">
#        <img src="http://barra.brasil.gov.br/imagens/vlibras.gif"/>
#        <span>
#         O conteúdo desse portal pode ser acessível em Libras usando o
#         <a href="http://www.vlibras.gov.br">
#          VLibras
#         </a>
#        </span>
#       </span>
#      </span>
#     </div>
#    </div>
#   </div>
#   <div id="wrapper">
#    <div id="header">
#     <div>
#      <div class="container text-left">
#       <ul class="text-left" id="accessibility">
#        <li>
#         <a accesskey="1" href="#acontent" id="link-conteudo">
#          Ir para o conteúdo
#          <span>
#           1
#          </span>
#         </a>
#        </li>
#        <li>
#         <a accesskey="2" href="#anavigation" id="link-navegacao">
#          Ir para o menu
#          <span>
#           2
#          </span>
#         </a>
#        </li>
#        <li>
#         <a accesskey="3" href="#asearch" id="link-buscar">
#          Ir para a busca
#          <span>
#           3
#          </span>
#         </a>
#        </li>
#        <li class="last-item">
#         <a accesskey="4" href="#afooter" id="link-rodape">
#          Ir para o rodapé
#          <span>
#           4
#          </span>
#         </a>
#        </li>
#       </ul>
#      </div>
#      <div class="container text-right">
#       <ul class="text-right" id="portal-siteactions">
#        <li id="siteaction-contraste">
#         <a accesskey="6" href="#" title="Alto Contraste">
#          Alto Contraste
#         </a>
#        </li>
#        <li class="last-item" id="siteaction-mapadosite">
#         <a accesskey="7" href="http://queimadas.dgi.inpe.br/queimadas/portal/mapadosite" title="Mapa do Site">
#          Mapa do Site
#         </a>
#        </li>
#       </ul>
#      </div>
#      <div class="container text-left align-top" id="container-logo">
#       <div class="text-left" id="logo">
#        <a href="http://queimadas.dgi.inpe.br/queimadas/portal" title="">
#         <img alt="" class="align-top" src="assets/images/simb_logo_conj.png" title="Programa Queimadas - INPE"/>
#         <div class="align-top">
#          <span id="portal-title-1">
#           Programa
#          </span>
#          <h1 class="corto" id="portal-title">
#           Queimadas
#          </h1>
#          <span id="portal-description">
#           Instituto Nacional de Pesquisas Espaciais
#          </span>
#         </div>
#        </a>
#       </div>
#      </div>
#      <div class="container text-right" id="container-search">
#       <div id="portal-searchbox">
#        <a id="asearch" name="asearch">
#        </a>
#        <form action="http://queimadas.dgi.inpe.br/queimadas/portal/@@busca" id="nolivesearchGadget_form">
#         <fieldset class="LSBox">
#          <input class="searchField" id="nolivesearchGadget" name="SearchableText" placeholder="Buscar no portal" size="18" title="Buscar no portal" type="text"/>
#          <input class="searchButton" type="submit" value="Buscar no portal"/>
#         </fieldset>
#        </form>
#       </div>
#       <div id="social-icons">
#        <ul>
#         <li class="portalredes-item" id="portalredes-flickr">
#          <a href="http://flickr.com/145994884@N08">
#           Flickr
#          </a>
#         </li>
#         <li class="portalredes-item" id="portalredes-facebook">
#          <a href="http://facebook.com/queimadasinpe">
#           Facebook
#          </a>
#         </li>
#         <li class="portalredes-item" id="portalredes-youtube">
#          <a href="http://youtube.com/channel/UCkzF8NS-HadR2CHXw3msMmg">
#           YouTube
#          </a>
#         </li>
#        </ul>
#       </div>
#      </div>
#     </div>
#     <div id="sobre">
#      <ul>
#       <li class="portalservicos-item">
#        <a href="http://queimadas.dgi.inpe.br/queimadas/">
#         <img alt="INPE" src="http://queimadas.dgi.inpe.br/queimadas/portal/logotipoinpe-menor-azul.png" title="INPE"/>
#        </a>
#       </li>
#       <li class="portalservicos-item" id="portalservicos-perguntas-frequentes">
#        <a href="http://queimadas.dgi.inpe.br/queimadas/portal/informacoes/perguntas-frequentes">
#         Perguntas Frequentes
#        </a>
#       </li>
#       <li class="portalservicos-item" id="portalservicos-noticias">
#        <a href="http://queimadas.dgi.inpe.br/queimadas/noticias/">
#         Notícias
#        </a>
#       </li>
#       <li class="portalservicos-item" id="portalservicos-dados-abertos">
#        <a href="http://queimadas.dgi.inpe.br/queimadas/dados-abertos/">
#         Dados Abertos
#        </a>
#       </li>
#       <li class="portalservicos-item" id="portalservicos-contato">
#        <a href="mailto:queimadas@inpe.br">
#         Contato
#        </a>
#       </li>
#       <li class="portalservicos-item">
#        <a href="http://queimadas.dgi.inpe.br/queimadas/diversidade/" target="_blank" title="Código de Conduta em Respeito à Diversidade">
#         <img alt="Imagem do logo do Código de Conduta em Respeito à Diversidade" src="http://queimadas.dgi.inpe.br/queimadas/portal/diversidade.png"/>
#        </a>
#        <a>
#        </a>
#       </li>
#      </ul>
#     </div>
#    </div>
#    <div id="main">
#     <a id="anavigation" name="anavigation">
#     </a>
#     <a id="acontent" name="acontent">
#     </a>
#     <div class="content-mapa">
#      <h1>
#       Situação Atual
#      </h1>
#      <span class="mensagem">
#       <a href="http://queimadas.dgi.inpe.br/queimadas/portal-static/situacao-atual/situacao-atual-light.php">
#        Ir para HTML básico (para casos de lentidão no carregamento)
#       </a>
#      </span>
#      <!-- mapa -->
#      <div class="mapa">
#       <div id="dvTituloMapa">
#        <span>
#         <span id="tituloMapa">
#          Situação Atual &gt; Focos 2 dias
#         </span>
#         <span id="subtituloMapa">
#          Dados gerados em 10/01/2020, entre 12 UTC e 18 UTC
#         </span>
#        </span>
#       </div>
#       <div class="leaflet-container leaflet-touch leaflet-retina leaflet-fade-anim leaflet-grab leaflet-touch-drag leaflet-touch-zoom" id="mapa" style="" tabindex="0">
#        <div class="leaflet-pane leaflet-map-pane" style="transform: translate3d(0px, 0px, 0px);">
#         <div class="leaflet-pane leaflet-tile-pane">
#          <div class="leaflet-layer" style="z-index: 1; opacity: 1;">
#           <div class="leaflet-tile-container leaflet-zoom-animated" style="z-index: 18; transform: translate3d(0px, 0px, 0px) scale(1);">
#            <img alt="" class="leaflet-tile leaflet-tile-loaded" role="presentation" src="https://b.tile.openstreetmap.org/4/5/8.png?service=WMS&amp;request=GetMap&amp;layers=&amp;styles=&amp;format=image%2Fpng&amp;transparent=true&amp;version=1.1.1&amp;width=256&amp;height=256&amp;srs=EPSG%3A4326&amp;bbox=-67.50000000000001,-21.94304553343818,-45,0" style="width: 256px; height: 256px; transform: translate3d(332px, 142px, 0px); opacity: 1;"/>
#            <img alt="" class="leaflet-tile leaflet-tile-loaded" role="presentation" src="https://a.tile.openstreetmap.org/4/5/7.png?service=WMS&amp;request=GetMap&amp;layers=&amp;styles=&amp;format=image%2Fpng&amp;transparent=true&amp;version=1.1.1&amp;width=256&amp;height=256&amp;srs=EPSG%3A4326&amp;bbox=-67.50000000000001,0,-45,21.94304553343818" style="width: 256px; height: 256px; transform: translate3d(332px, -114px, 0px); opacity: 1;"/>
#            <img alt="" class="leaflet-tile leaflet-tile-loaded" role="presentation" src="https://a.tile.openstreetmap.org/4/4/8.png?service=WMS&amp;request=GetMap&amp;layers=&amp;styles=&amp;format=image%2Fpng&amp;transparent=true&amp;version=1.1.1&amp;width=256&amp;height=256&amp;srs=EPSG%3A4326&amp;bbox=-90,-21.94304553343818,-67.50000000000001,0" style="width: 256px; height: 256px; transform: translate3d(76px, 142px, 0px); opacity: 1;"/>
#            <img alt="" class="leaflet-tile leaflet-tile-loaded" role="presentation" src="https://c.tile.openstreetmap.org/4/6/8.png?service=WMS&amp;request=GetMap&amp;layers=&amp;styles=&amp;format=image%2Fpng&amp;transparent=true&amp;version=1.1.1&amp;width=256&amp;height=256&amp;srs=EPSG%3A4326&amp;bbox=-45,-21.94304553343818,-22.5,0" style="width: 256px; height: 256px; transform: translate3d(588px, 142px, 0px); opacity: 1;"/>
#            <img alt="" class="leaflet-tile leaflet-tile-loaded" role="presentation" src="https://c.tile.openstreetmap.org/4/5/9.png?service=WMS&amp;request=GetMap&amp;layers=&amp;styles=&amp;format=image%2Fpng&amp;transparent=true&amp;version=1.1.1&amp;width=256&amp;height=256&amp;srs=EPSG%3A4326&amp;bbox=-67.50000000000001,-40.979898069620134,-45,-21.94304553343818" style="width: 256px; height: 256px; transform: translate3d(332px, 398px, 0px); opacity: 1;"/>
#            <img alt="" class="leaflet-tile leaflet-tile-loaded" role="presentation" src
, 0px); opacity: 1;"/>
#            <img alt="" class="leaflet-tile leaflet-tile-loaded" role="presentation" src="http://sirc.dgi.inpe.br/cgi-bin/mapserv?map=/home/queimadas/mapserver/mapfiles/area_queimada.map&amp;&amp;service=WMS&amp;request=GetMap&amp;layers=focos24h&amp;styles=&amp;format=image%2Fpng&amp;transparent=true&amp;version=1.1.1&amp;width=256&amp;height=256&amp;srs=EPSG%3A4326&amp;bbox=-112.50000000000001,0,-90,21.94304553343818" style="width: 256px; height: 256px; transform: translate3d(-180px, -114px, 0px); opacity: 1;"/>
#            <img alt="" class="leaflet-tile leaflet-tile-loaded" role="presentation" src="http://sirc.dgi.inpe.br/cgi-bin/mapserv?map=/home/queimadas/mapserver/mapfiles/area_queimada.map&amp;&amp;service=WMS&amp;request=GetMap&amp;layers=focos24h&amp;styles=&amp;format=image%2Fpng&amp;transparent=true&amp;version=1.1.1&amp;width=256&amp;height=256&amp;srs=EPSG%3A4326&amp;bbox=-22.5,0,0,21.94304553343818" style="width: 256px; height: 256px; transform: translate3d(844px, -114px, 0px); opacity: 1;"/>
#            <img alt="" class="leaflet-tile leaflet-tile-loaded" role="presentation" src="http://sirc.dgi.inpe.br/cgi-bin/mapserv?map=/home/queimadas/mapserver/mapfiles/area_queimada.map&amp;&amp;service=WMS&amp;request=GetMap&amp;layers=focos24h&amp;styles=&amp;format=image%2Fpng&amp;transparent=true&amp;version=1.1.1&amp;width=256&amp;height=256&amp;srs=EPSG%3A4326&amp;bbox=-112.50000000000001,-40.979898069620134,-90,-21.94304553343818" style="width: 256px; height: 256px; transform: translate3d(-180px, 398px, 0px); opacity: 1;"/>
#            <img alt="" class="leaflet-tile leaflet-tile-loaded" role="presentation" src="http://sirc.dgi.inpe.br/cgi-bin/mapserv?map=/home/queimadas/mapserver/mapfiles/area_queimada.map&amp;&amp;service=WMS&amp;request=GetMap&amp;layers=focos24h&amp;styles=&amp;format=image%2Fpng&amp;transparent=true&amp;version=1.1.1&amp;width=256&amp;height=256&amp;srs=EPSG%3A4326&amp;bbox=-22.5,-40.979898069620134,0,-21.94304553343818" style="width: 256px; height: 256px; transform: translate3d(844px, 398px, 0px); opacity: 1;"/>
#           </div>
#          </div>
#         </div>
#         <div class="leaflet-pane leaflet-shadow-pane">
#         </div>
#         <div class="leaflet-pane leaflet-overlay-pane">
#         </div>
#         <div class="leaflet-pane leaflet-marker-pane">
#         </div>
#         <div class="leaflet-pane leaflet-tooltip-pane">
#         </div>
#         <div class="leaflet-pane leaflet-popup-pane">
#         </div>
#         <div class="leaflet-proxy leaflet-zoom-animated" style="transform: translate3d(1444.98px, 2225.41px, 0px) scale(8);">
#         </div>
#        </div>
#        <div class="leaflet-control-container">
#         <div class="leaflet-top leaflet-left">
#          <div class="leaflet-control-zoom leaflet-bar leaflet-control">
#           <a aria-label="Zoom in" class="leaflet-control-zoom-in" href="#" role="button" title="Zoom in">
#            +
#           </a>
#           <a aria-label="Zoom out" class="leaflet-control-zoom-out" href="#" role="button" title="Zoom out">
#            −
#           </a>
#          </div>
#          <div class="leaflet-control-fullscreen leaflet-bar leaflet-control">
#           <a class="leaflet-control-fullscreen-button leaflet-bar-part" href="#" title="View Fullscreen">
#           </a>
#          </div>
#          <div class="leaflet-bar leaflet-control leaflet-control-geosearch">
#           <a class="leaflet-bar-part leaflet-bar-part-single glass" href="#" title="Insira um endereço">
#           </a>
#           <form class="displayNone">
#            <input class="" placeholder="Insira um endereço" type="text"/>
#           </form>
#           <div class="leaflet-bar message displayNone">
#           </div>
#          </div>
#          <div class="leaflet-bar leaflet-control ui-slider ui-corner-all ui-slider-vertical ui-widget ui-widget-content" id="slider">
#           <div class="ui-slider-range ui-corner-all ui-widget-header ui-slider-range-min" style="height: 100%;">
#           </div>
#           <span class="ui-slider-handle ui-corner-all ui-state-default" style="bottom: 100%;" tabindex="0">
#           </span>
#          </div>
#         </div>
#         <div class="leaflet-top leaflet-right">
#          <div aria-haspopup="true" class="leaflet-control-layers leaflet-control-layers-expanded leaflet-control">
#           <a class="leaflet-control-layers-toggle" href="#" title="Layers">
#           </a>
#           <section class="leaflet-control-layers-list">
#            <div class="leaflet-control-layers-base">
#             <label>
#              <div>
# ...
#         Tabela anual comparativa de países - últimos anos no intervalo de 01/Jan até 10/Jan
#        </h2>
#        <span>
#         * Número de focos detectados pelo satélite de referência entre 01/01 a 10/01 de cada ano.
#        </span>
#        <ul class="nav_graficos">
#         <li class="active" onclick="changeTable('paises',null,'7anos');" title="Últimos 7 anos">
#          <span>
#           Últimos 7 anos
#          </span>
#         </li>
#         <li onclick="changeTable('paises',null,'estendida');" title="Todos os anos">
#          <span>
#           Todos os anos
#          </span>
#         </li>
#        </ul>
#        <section>
#         <iframe id="comparativa-paises" onload="resizeIframe(this)" src="../focos_paises_anual_7anos.html?_=01112002" style="height: 350px;">
#         </iframe>
#         <a href="http://queimadas.dgi.inpe.br/queimadas/portal/estatistica_paises" target="_blank">
#          Ir para estatísticas dos países
#          <span class="fas fa-arrow-circle-right">
#          </span>
#         </a>
#        </section>
#       </div>
#       <!-- comparativo_estados -->
#       <div class="comparativo">
#        <h2 id="titestados">
#         Tabela anual comparativa de estados do Brasil - últimos anos no intervalo de 01/Jan até 10/Jan
#        </h2>
#        <span>
#         * Número de focos detectados pelo satélite de referência.
#        </span>
#        <ul class="nav_graficos">
#         <li class="active" onclick="changeTable('estados',null,'7anos');" title="Últimos 7 anos">
#          <span>
#           Últimos 7 anos
#          </span>
#         </li>
#         <li onclick="changeTable('estados',null,'estendida');" title="Todos os anos">
#          <span>
#           Todos os anos
#          </span>
#         </li>
#        </ul>
#        <section>
#         <iframe id="comparativa-estados" onload="resizeIframe(this)" src="../focos_estados_anual_7anos.html?_=01112002" style="overflow-y: auto; height: 652px;">
#         </iframe>
#         <a href="http://queimadas.dgi.inpe.br/queimadas/portal/estatistica_estados" target="_blank">
#          Ir para estatísticas dos estados, regiões e biomas
#          <span class="fas fa-arrow-circle-right">
#          </span>
#         </a>
#        </section>
#       </div>
#       <!-- comparativo_regiao -->
#       <div class="comparativo">
#        <h2 id="titregiao">
#         Tabela anual comparativa de regiões do Brasil - últimos anos no intervalo de 01/Jan até 10/Jan
#        </h2>
#        <span>
#         * Número de focos detectados pelo satélite de referência.
#        </span>
#        <ul class="nav_graficos">
#         <li class="active" onclick="changeTable('regiao_brasil',null,'7anos');" title="Últimos 7 anos">
#          <span>
#           Últimos 7 anos
#          </span>
#         </li>
#         <li onclick="changeTable('regiao_brasil',null,'estendida');" title="Todos os anos">
#          <span>
#           Todos os anos
#          </span>
#         </li>
#        </ul>
#        <section>
#         <iframe id="comparativa-regiao_brasil" onload="resizeIframe(this)" src="../focos_regiao_brasil_anual_7anos.html?_=01112002" style="overflow-y: auto; height: 165px;">
#         </iframe>
#         <a href="http://queimadas.dgi.inpe.br/queimadas/portal/estatistica_estados" target="_blank">
#          Ir para estatísticas dos estados, regiões e biomas
#          <i class="fas fa-arrow-circle-right">
#          </i>
#         </a>
#        </section>
#       </div>
#       <!-- comparativo_regiao_especial -->
#       <div class="comparativo">
#        <h2 id="titregiao">
#         Tabela anual comparativa de regiões especiais do Brasil - últimos anos no intervalo de 01/Jan até 10/Jan
#        </h2>
#        <span>
#         * Número de focos detectados pelo satélite de referência.
#        </span>
#        <ul class="nav_graficos">
#         <li class="active" onclick="changeTable('regiao',null,'7anos');" title="Últimos 7 anos">
#          <span>
#           Últimos 7 anos
#          </span>
#         </li>
#         <li onclick="changeTable('regiao',null,'estendida');" title="Todos os anos">
#          <span>
#           Todos os anos
#          </span>
#         </li>
#        </ul>
#        <section>
#         <iframe id="comparativa-regiao" onload="resizeIframe(this)" src="../focos_regiao_anual_7anos.html?_=01112002" style="overflow-y: auto; height: 100px;">
#         </iframe>
#         <a href="http://queimadas.dgi.inpe.br/queimadas/portal/estatistica_estados" target="_blank">
#          Ir para estatísticas dos estados, regiões e biomas
#          <i class="fas fa-arrow-circle-right">
#          </i>
#         </a>
#        </section>
#       </div>
#       <!-- comparativo_bioma -->
#       <div class="comparativo">
#        <h2 id="titbioma">
#         Tabela anual comparativa de biomas do Brasil - últimos anos no intervalo de 01/Jan até 10/Jan
#        </h2>
#        <span>
#         * Número de focos detectados pelo satélite de referência.
#        </span>
#        <ul class="nav_graficos">
#         <li class="active" onclick="changeTable('bioma',null,'7anos');" title="Últimos 7 anos">
#          <span>
#           Últimos 7 anos
#          </span>
#         </li>
#         <li onclick="changeTable('bioma',null,'estendida');" title="Todos os anos">
#          <span>
#           Todos os anos
#          </span>
#         </li>
#        </ul>
#        <section>
#         <iframe id="comparativa-bioma" onload="resizeIframe(this)" src="../focos_bioma_anual_7anos.html?_=01112002" style="overflow-y: auto; height: 188px;">
#         </iframe>
#         <a href="http://queimadas.dgi.inpe.br/queimadas/portal/estatistica_estados" target="_blank">
#          Ir para estatísticas dos estados, regiões e biomas
#          <i class="fas fa-arrow-circle-right">
#          </i>
#         </a>
#        </section>
#       </div>
#      </div>
#     </div>
#    </div>
#    <div class="topo">
#     <a accesskey="0" href="#wrapper">
#      Ir para o topo
#     </a>
#     <ul class="text-left" id="accessibility">
#      <li>
#       <a accesskey="1" href="#acontent" id="link-conteudo">
#        Ir para o conteúdo
#        <span>
#         1
#        </span>
#       </a>
#      </li>
#      <li>
#       <a accesskey="2" href="#anavigation" id="link-navegacao">
#        Ir para o menu
#        <span>
#         2
#        </span>
#       </a>
#      </li>
#      <li>
#       <a accesskey="3" href="#asearch" id="link-buscar">
#        Ir para a busca
#        <span>
#         3
#        </span>
#       </a>
#      </li>
#      <li class="last-item">
#       <a accesskey="4" href="#afooter" id="link-rodape">
#        Ir para o rodapé
#        <span>
#         4
#        </span>
#       </a>
#      </li>
#     </ul>
#    </div>
#    <div class="loader" id="loader">
#     <img alt="Carregando..." src="assets/images/spinner.gif"/>
#    </div>
#    <div id="footer" role="contentinfo">
#     <a id="afooter" name="afooter">
#     </a>
#     <div class="row sitemap">
#      <dl class="col-6 col-sm-6 col-md-3 col-lg-3 col-xl-3">
#       <dt>
#        Informações
#       </dt>
#       <dd>
#        <a class="external-link" href="http://queimadas.dgi.inpe.br/queimadas/portal/informacoes/apresentacao" target="_blank">
#         Apresentação
#        </a>
#       </dd>
#       <dd>
#        <a class="external-link" href="http://queimadas.dgi.inpe.br/queimadas/portal/informacoes/perguntas-frequentes">
#         Perguntas Frequentes
#        </a>
#       </dd>
#       <dd>
#        <a class="external-link" href="http://queimadas.dgi.inpe.br/queimadas/portal/agradecimentos">
#         Agradecimentos
#        </a>
#       </dd>
#       <dd>
#        <a class="external-link" href="http://queimadas.dgi.inpe.br/queimadas/portal/equipe">
#         Equipe
#        </a>
#       </dd>
#       <dd>
#        <a class="external-link" href="http://queimadas.dgi.inpe.br/queimadas/portal/links-adicionais/links-e-material-de-30s">
#         Links Externos
#        </a>
#       </dd>
#      </dl>
#      <dl class="col-6 col-sm-6 col-md-3 col-lg-3 col-xl-3">
#       <dt>
#        Sistemas
#       </dt>
#       <dd>
#        <a class="external-link" href="http://queimadas.dgi.inpe.br/queimadas/bdqueimadas">
#         BDQueimadas
#        </a>
#       </dd>
#       <dd>
#        <a class="external-link" href="http://queimadas.dgi.inpe.br/queimadas/ciman">
#         Ciman Virtual
#        </a>
#       </dd>
#       <dd>
#        <a class="external-link" href="http://queimadas.dgi.inpe.br/queimadas/cadastro/v1/relatorio-ucs/" target="_blank">
#         Focos nas APs
#        </a>
#       </dd>
#       <dd>
#        <a class="external-link" href="http://queimadas.dgi.inpe.br/queimadas/portal/risco-de-fogo-meteorologia" target="_blank">
#         Risco de Fogo
#        </a>
#       </dd>
#       <dd>
#        <a class="external-link" href="http://queimadas.dgi.inpe.br/queimadas/sisam">
#         Sisam
#        </a>
#       </dd>
#      </dl>
#      <dl class="col-6 col-sm-6 col-md-3 col-lg-3 col-xl-3">
#       <dt>
#        Relatórios
#       </dt>
#       <dd>
#        <a class="external-link" href="http://queimadas.dgi.inpe.br/queimadas/portal/outros-produtos/situacao-atual">
#         Situação Atual
#        </a>
#       </dd>
#       <dd>
#        <a class="external-link" href="http://queimadas.dgi.inpe.br/queimadas/cadastro/v2/">
#         Relatório Diário
#        </a>
#       </dd>
#       <dd>
#        <a class="external-link" href="http://queimadas.dgi.inpe.br/queimadas/ciman/briefings">
#         Briefings meteorológicos
#        </a>
#       </dd>
#       <dd>
#        <a class="external-link" href="http://queimadas.dgi.inpe.br/queimadas/portal/outros-produtos/infoqueimada">
#         InfoQueima
#        </a>
#       </dd>
#       <dd>
#        <a class="external-link" href="http://www.ibama.gov.br/index.php?option=com_content&amp;view=article&amp;id=549&amp;Itemid=488" target="_blank">
#         PrevFogo/IBAMA
#        </a>
#       </dd>
#      </dl>
#      <dl class="col-6 col-sm-6 col-md-3 col-lg-3 col-xl-3">
#       <dt>
#        Publicações
#       </dt>
#       <dd>
#        <a class="external-link" href="http://queimadas.cptec.inpe.br/~rqueimadas/documentos/pub_queimadas.pdf" target="_blank">
#         Referenciadas
#        </a>
#       </dd>
#       <dd>
#        <a class="external-link" href="http://queimadas.dgi.inpe.br/queimadas/portal/links-adicionais/na-midia">
#         Na Mídia
#        </a>
#       </dd>
#       <dt>
#        Contato
#       </dt>
#       <dd>
#        <a class="external-link" href="mailto:queimadas@inpe.br">
#         E-mail
#        </a>
#       </dd>
#      </dl>
#     </div>
#     <div class="footer-logos" id="footer-brasil">
#      <div id="wrapper-footer-brasil">
#       <a href="http://www.acessoainformacao.gov.br/">
#        <span class="logo-acesso-footer">
#        </span>
#       </a>
#       <a href="http://www.brasil.gov.br/">
#        <span class="logo-brasil-footer">
#        </span>
#       </a>
#      </div>
#     </div>
#    </div>
#    <script defer="defer" src="http://barra.brasil.gov.br/barra.js" type="text/javascript">
#    </script>
#    <script type="text/javascript">
#     var mapa,
#   tipo = {'regiao_brasil':'7anos','bioma':'7anos','regiao':'7anos','estados':'7anos','paises':'7anos','box-paises':'tabela','box-estado':'mapa','box-municipio':'barra','box-bioma':'pizza'},
#   tempo = {'regiao_brasil':'anual','bioma':'anual','regiao':'anual','estados':'anual','paises':'anual','box-paises':'ano_atual','box-estado':'ano_atual','box-municipio':'ano_atual','box-bioma':'ano_atual'},
#   d = new Date(),
#   mapserver = "http://sirc.dgi.inpe.br/cgi-bin/mapserv?map=",
#   map_risco = mapserver+"/dados/mapfiles/riscofogo.map&amp;",
#   map_meteorologia = mapserver+"/srv/queimadas/meteorologia/mapfiles/meteorologia.map&amp;",
#   map_aq = mapserver+"/home/queimadas/mapserver/mapfiles/area_queimada.map&amp;",
#   map_dsa = "http://sigma.cptec.inpe.br/cgi-bin/mapserv?map=/extra2/sigma/www/webservice/webservice_dsa.map&amp;",
#   map_terreno = 'https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png',
#   opcoes = {
#     attribution: '&amp;copy; 1998 - 2019 &lt;a target="_blank" href="http://queimadas.dgi.inpe.br/queimadas/"&gt;INPE - Queimadas&lt;/a&gt;'
#   };
#
# function getTileLayer(wms,params){
#   var opt = {format:'image/png',transparent:true,crs:L.CRS.EPSG4326};
#   if(typeof params !== "undefined"){Object.assign(opt, params);}
#   return L.tileLayer.wms(wms,opt);
# }
#
# var terreno = getTileLayer(map_terreno,opcoes),
#     contornoPaises = getTileLayer(map_meteorologia,{layers:'geo_paises'}),
#     focos = getTileLayer(map_aq,{layers:'focos24h'}),
#     nuvens = getTileLayer(map_dsa,{layers:'ULT_CH13G16RGB'}),
#     fumaca = getTileLayer("http://queimadas.dgi.inpe.br/queimadas/terrama2q/geoserver/ows",{layers:'view72',time:"2020-01-09"}),
#     rfPrev1d = getTileLayer(map_risco, {layers:'previsao_rf_prev1d',dia:"11",mes:"01",ano:"2020",dtref:"20200111"}),
#     nuvens_control = getTileLayer(map_dsa,{layers:'ULT_CH13G16RGB'}),
#     terreno_control = getTileLayer(map_terreno,opcoes);
#
# function getLayersSituacaoAtual(mapa) {
#   	controlLayers = L.control.layers({
# 		'Nuvens': nuvens_control,
# 		'Risco de Fogo': rfPrev1d,
# 		'Fumaça': fumaca,
# 		'Terreno': terreno_control,
# 	}, {}, {collapsed:false}).addTo(mapa);
#
# 	ctrl = [focos, contornoPaises,controlLayers,[nuvens,rfPrev1d,fumaca,terreno_control],terreno];
#
# 	return ctrl;
# }
#
# function changeTable(unidade,tmp,tp){
#   var id_obj,un,label_tp;
#
#   if(tmp){tempo[unidade]=tmp;}
#   if(tp){tipo[unidade]=tp;}
#   tmp = tempo[unidade];
#   tp = tipo[unidade];
#
#   label_tp=tp=="tabela"?"":"_"+tp;
#   if(unidade.indexOf("box-")&lt;0){
#       un = unidade;
#       id_obj = "#comparativa-"+un;
#   }else{
#       un = unidade.replace("box-","");
#       $("#div-focos-"+un+" .inline li").removeClass("active");
#       $("#div-focos-"+un+" .img_"+tmp+",#div-focos-"+un+" .img_"+tp).parent().addClass("active");
#       var lbl = 'PERÍODO';
#       switch(tmp){
#           case 'mes_atual':
#               lbl += " MENSAL: ATÉ 10/01/2020";
#               break;
#           case '48h':
#               lbl += ": ÚLTIMAS "+tmp.toUpperCase();
#               break;
#           case 'ano_atual':
#           default:
#               lbl += " ANUAL: "+d.getFullYear();
#       }
#       $("#div-focos-"+un).find(".descTempo").html(lbl);
#       id_obj = "#focos-"+un;
#   }
#   if($(id_obj).length==0) return;
#   $(id_obj).attr("src",tp=="mapa"?("mapas.php?tmp="+tmp+"&amp;un="+un):("../focos_"+un+"_"+tmp+label_tp+".html?_=01112002"));
# }
#
# function updateLogo(){$('#logo img').attr("src","assets/images/simb_logo"+($(window).width()&lt;920?'':'_conj')+".png");}
#
# $(document).ready(function() {
#     mapa = L.map('mapa', {
#       zoom:8,
#       minZoom:0,
#       center:[-15.8, -47.9],
#       layers:[terreno,nuvens,contornoPaises,focos],
#       fullscreenControl:true
#     }).fitBounds([[-34,-75.0],[5,-31]]);
#
#     mapa.on('resize',function(e){mapa.fitBounds([[-34,-75.0],[5,-31]]);});
#     mapa.on('overlayadd',function(l){ contornoPaises.bringToFront();focos.bringToFront();});
#     mapa.on('baselayerchange',function(l){contornoPaises.bringToFront();focos.bringToFront();$("#slider").slider('value',100);});
#
#     L.control.scale().addTo(mapa);
#
#     new L.Control.GeoSearch({provider: new L.GeoSearch.Provider.OpenStreetMap()}).addTo(mapa);
#
#     ctrl = getLayersSituacaoAtual(mapa);
#     activeLayer = ctrl[3];
#
#     $(".leaflet-left").append($("#slider").addClass("leaflet-bar leaflet-control"));
#     $("#mapa").append($("#legenda_mapa"));
#
#     $("#slider").slider({
#       value:100,
#       orientation:"vertical",
#       range:"min",
#       animate:true,
#       change:function(event,ui){
#         for(var i=0; i&lt;activeLayer.length; i++){
#           activeLayer[i].setOpacity(parseFloat(ui.value)/100);
#         }
#       }
#     });
#
#     $.each(tipo,function(k,v){changeTable(k);})
#
#     if($(".topo ul").length == 0){$(".topo").append($("#accessibility").clone());}
#     $('body').on('click','.comparativo li',function(){
#         $(this).parent().children().removeClass("active");
#         $(this).addClass("active");
#     })
#     updateLogo();
# });
# $(window).resize(function(){updateLogo()});
#    </script>
#    <!-- Global site tag (gtag.js) - Google Analytics -->
#    <script async="" src="https://www.googletagmanager.com/gtag/js?id=UA-121460145-1">
#    </script>
#    <script>
#     window.dataLayer = window.dataLayer || [];
# 	function gtag(){dataLayer.push(arguments);}
# 	gtag('js', new Date());
#
# 	gtag('config', 'UA-121460145-1');
#    </script>
#   </div>
#  </body>
# </html>
